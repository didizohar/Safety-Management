# %%
# !pip install ipympl
# Out:
# Requirement already satisfied: ipympl in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (0.9.4)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (3.5.2)
# Requirement already satisfied: ipython-genutils in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: ipython<9 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (8.4.0)
# Requirement already satisfied: pillow in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (9.2.0)
# Requirement already satisfied: traitlets<6 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: numpy in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (1.21.5)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipympl) (7.6.5)
# Requirement already satisfied: stack-data in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: appnope in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (63.4.1)
# Requirement already satisfied: pickleshare in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (3.0.20)
# Requirement already satisfied: backcall in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: decorator in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.15.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (24.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (8.6.2)
# Requirement already satisfied: pyzmq>=17 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (26.1.0)
# Requirement already satisfied: nest-asyncio in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.4.1)
# Requirement already satisfied: psutil in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: fastjsonschema in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.2)
# Requirement already satisfied: jupyter_core in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (5.7.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.12)
# Requirement already satisfied: asttokens in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: executing in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: pure-eval in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (24.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.20.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (4.11.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (2.5.2)
# Requirement already satisfied: nbconvert>=5 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.4)
# Requirement already satisfied: terminado>=0.8.3 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.13.1)
# Requirement already satisfied: argon2-cffi in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: prometheus-client in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: jinja2 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.3)
# Requirement already satisfied: zipp>=0.5 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (3.8.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: defusedxml in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: testpath in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.6.0)
# Requirement already satisfied: bleach in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.1)
# Requirement already satisfied: webencodings in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in /Users/didizohar/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import statsmodels.api as sm
import pickle as pkl
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib widget

# %% [markdown]
# # Students :
# ### - Sahar Jerbi - 206775603
# ### - Maxim Polak - 209383322
# ### - David Moshe Zohar - 209160977
# ### - Daniel Gross - 208328161

# %%
df = pkl.load( open('../ניהול בטיחות למהנדסים/project_part_1_group_18.pkl', 'rb'))
df.head()
# Out:
#    Intercept       temp  rigid_left__c  is_mathane
# 0        1.0  41.709126           True       False
# 1        1.0  41.880191          False        True
# 2        1.0  17.099422          False       False
# 3        1.0  25.619566          False        True
# 4        1.0  44.750792           True       False

# %%
df.shape
# Out:
# (120, 4)

# %%
df.isna().sum()
# Out:
# Intercept        0
# temp             0
# rigid_left__c    0
# is_mathane       0
# dtype: int64

# %%
df['is_mathane'] = df['is_mathane'].astype(int)
df['rigid_left__c'] = df['rigid_left__c'].astype(int)
df.head()
# Out:
#    Intercept       temp  rigid_left__c  is_mathane
# 0        1.0  41.709126              1           0
# 1        1.0  41.880191              0           1
# 2        1.0  17.099422              0           0
# 3        1.0  25.619566              0           1
# 4        1.0  44.750792              1           0

# %% [markdown]
# ---

# %% [markdown]
# # PART 1
# # Q1 :

# %%
x = df[['Intercept', 'temp', 'rigid_left__c']]
y = df['is_mathane']

# %%
Logistic_Model = sm.Logit(y,x)
OurModel = Logistic_Model.fit()
print(OurModel.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.500576
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             is_mathane   No. Observations:                  120
# Model:                          Logit   Df Residuals:                      117
# Method:                           MLE   Df Model:                            2
# Date:                Fri, 16 Aug 2024   Pseudo R-squ.:                  0.2630
# Time:                        09:24:53   Log-Likelihood:                -60.069
# converged:                       True   LL-Null:                       -81.503
# Covariance Type:            nonrobust   LLR p-value:                 4.912e-10
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         3.1465      0.757      4.158      0.000       1.663       4.630
# temp             -0.0801      0.021     -3.735      0.000      -0.122      -0.038
# rigid_left__c    -2.3809      0.488     -4.883      0.000      -3.337      -1.425
# =================================================================================

# %%
OurModel_aic , OurModel_bic = OurModel.aic , OurModel.bic

# %%
print('AIC =',OurModel_aic)
print('BIC =',OurModel_bic)
# Out:
# AIC = 126.13814529142662
# BIC = 134.50062051977275

# %% [markdown]
# ### Logistic regression equation:
# $$
# P(\text{Is_Mathane}) = \frac{1}{1+e^{-(3.1465 + (-0.0801) \cdot \text{temp} + (-2.3809) \cdot \text{rigid_left__c})}}
# $$
# ---
# ---

# %% [markdown]
# # Q2

# %%
df['prediction'] = OurModel.predict(df[['Intercept', 'temp', 'rigid_left__c']])
df.head()
# Out:
#    Intercept       temp  rigid_left__c  is_mathane  prediction
# 0        1.0  41.709126              1           0    0.070741
# 1        1.0  41.880191              0           1    0.448149
# 2        1.0  17.099422              0           0    0.855306
# 3        1.0  25.619566              0           1    0.749201
# 4        1.0  44.750792              1           0    0.056306

# %%
fprs = []
sensi = []
thresholds = np.linspace(0,1,20)

for threshold in thresholds:

    df['classification'] = df['prediction'].apply(lambda x: 1 if x > threshold else 0)

    y_pred = df['classification']
    y = df['is_mathane']
    confusion_matrix_ = confusion_matrix(y, y_pred)


    sensitivity_ = confusion_matrix_[1,1]/(confusion_matrix_[1,0]+confusion_matrix_[1,1])
    specificty_ = confusion_matrix_[0,0]/(confusion_matrix_[0,1]+confusion_matrix_[0,0])
    fpr = 1-specificty_
    
    fprs.append(fpr)
    sensi.append(sensitivity_)

plt.figure()
plt.scatter( fprs, sensi)
plt.xlabel('FPR(1-Specificty)', fontsize = 15)
plt.ylabel('TPR(Sensitivity)', fontsize = 15)
plt.title('ROC', fontsize = 20)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
thresholds
# Out:
# array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#        0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#        0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#        0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ])

# %% [markdown]
# ## We can see here that the threshold that will give us Sensitivity and Specificty above 0.6 will be somewhere between 0.315 to 0.473 but we will do some manual tests to get the specific answer

# %%
logreg = LogisticRegression()
logreg.fit( df[['Intercept', 'temp', 'rigid_left__c']], df['is_mathane'])
# Out:
# LogisticRegression()

# %%
logit_roc_auc = roc_auc_score(df['is_mathane'], logreg.predict(df[['Intercept', 'temp', 'rigid_left__c']]))
fpr, tpr, thresholds = roc_curve(df['is_mathane'], logreg.predict_proba(df[['Intercept', 'temp', 'rigid_left__c']])[:,1])

plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize = 15)
plt.ylabel('True Positive Rate', fontsize = 15)
plt.title('Receiver operating characteristic', fontsize = 15)
plt.legend(loc="lower right")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_predict = df[['Intercept', 'temp' ,'rigid_left__c']]

# %%
TP = sum((OurModel.predict(data_predict) > 0.3) & (df["is_mathane"] == 1))
FP = sum((OurModel.predict(data_predict) > 0.3) & (df["is_mathane"] == 0))
TN = sum((OurModel.predict(data_predict) <= 0.3) & (df["is_mathane"] == 0))
FN = sum((OurModel.predict(data_predict) <= 0.3) & (df["is_mathane"] == 1))
TP,FP,TN,FN
# Out:
# (46, 26, 44, 4)

# %%
threshold = 0.3
df['classification'] = df['prediction'].apply(lambda x: 1 if x > threshold else 0)
y_pred = df['classification']
y = df['is_mathane']
confusion_matrix_ = confusion_matrix(y, y_pred)
sensitivity_ = confusion_matrix_[1,1]/(confusion_matrix_[1,0]+confusion_matrix_[1,1])
specificty_ = confusion_matrix_[0,0]/(confusion_matrix_[0,1]+confusion_matrix_[0,0])
fpr = 1- specificty_
sensitivity_,specificty_, fpr
# Out:
# (0.92, 0.6285714285714286, 0.37142857142857144)

# %%
cm = confusion_matrix(df['is_mathane'], df['classification'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=np.array([0,1]))
disp.plot()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
TP = sum((OurModel.predict(data_predict) > 0.48) & (df["is_mathane"] == 1))
FP = sum((OurModel.predict(data_predict) > 0.48) & (df["is_mathane"] == 0))
TN = sum((OurModel.predict(data_predict) <= 0.48) & (df["is_mathane"] == 0))
FN = sum((OurModel.predict(data_predict) <= 0.48) & (df["is_mathane"] == 1))
TP,FP,TN,FN
# Out:
# (31, 13, 57, 19)

# %%
threshold = 0.48
df['classification'] = df['prediction'].apply(lambda x: 1 if x > threshold else 0)
y_pred = df['classification']
y = df['is_mathane']
confusion_matrix_ = confusion_matrix(y, y_pred)
sensitivity_ = confusion_matrix_[1,1]/(confusion_matrix_[1,0]+confusion_matrix_[1,1])
specificty_ = confusion_matrix_[0,0]/(confusion_matrix_[0,1]+confusion_matrix_[0,0])
fpr = 1- specificty_
sensitivity_,specificty_, fpr
# Out:
# (0.62, 0.8142857142857143, 0.18571428571428572)

# %%
cm = confusion_matrix(df['is_mathane'], df['classification'])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=np.array([0,1]))
disp.plot()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## After a few manual tests we found the threshold range and it is between 0.3 to 0.48

# %% [markdown]
# ---

# %% [markdown]
# # Q3

# %%
def calculate_metrics(y_true, y_pred, threshold):
    y_pred_thresholded = (y_pred >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred_thresholded).ravel()
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    return accuracy

def find_optimal_threshold(y_true, y_pred, min_threshold=0.01, max_threshold=0.99, step=0.01):
    best_accuracy = 0
    optimal_thresholds = []
    
    for threshold in np.arange(min_threshold, max_threshold, step):
        accuracy = calculate_metrics(y_true, y_pred, threshold)
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            optimal_thresholds = [threshold]
        elif accuracy == best_accuracy:
            optimal_thresholds.append(threshold)
    
    return best_accuracy, optimal_thresholds

y_true = df['is_mathane']
y_pred = df['prediction']

best_accuracy, optimal_thresholds = find_optimal_threshold(y_true, y_pred)
print(f"Best Accuracy: {best_accuracy}")
print(f"Optimal Thresholds: {optimal_thresholds}")
# Out:
# Best Accuracy: 0.7833333333333333
# Optimal Thresholds: [0.34, 0.35000000000000003, 0.38, 0.39]

# %% [markdown]
# ### The best accuracy is 0.7833333333333333
# ### The Threshold values for that accuracy is : 0.34, 0.35000000000000003, 0.38, 0.39

# %% [markdown]
# # The predictions

# %%
pred_df = pd.DataFrame([])
pred_df.loc[0,'Intercept'] = 1
pred_df.loc[0,'temp'] = 25.5
pred_df.loc[0,'rigid_left__c'] = 1
pred_df.loc[1,'Intercept'] = 1
pred_df.loc[1,'temp'] = 26.5
pred_df.loc[1,'rigid_left__c'] = 1
pred_df.loc[2,'Intercept'] = 1
pred_df.loc[2,'temp'] = 27.5
pred_df.loc[2,'rigid_left__c'] = 1
pred_df.head()
# Out:
#    Intercept  temp  rigid_left__c
# 0        1.0  25.5            1.0
# 1        1.0  26.5            1.0
# 2        1.0  27.5            1.0

# %%
is_mathane_prob_a = OurModel.predict(pred_df[['Intercept', 'temp', 'rigid_left__c']])
is_mathane_prob_a
# Out:
# 0    0.218064
# 1    0.204715
# 2    0.191982
# dtype: float64

# %% [markdown]
# ### a.

# %%
is_mathane_prob_a[0]
# Out:
# 0.21806446969071117

# %% [markdown]
# ### The probability that it will be a methane when the temperature is 25.5 and there is some lumps is : 0.21806446969071108
# ---

# %% [markdown]
# ### b.

# %%
is_mathane_prob_a[1]
# Out:
# 0.2047147334007214

# %% [markdown]
# ### The probability that it will be a methane when the temperature is 26.5 and there is some lumps is : 0.20471473340072133
# ---

# %% [markdown]
# ### c.

# %%
is_mathane_prob_a[2]
# Out:
# 0.19198160292141878

# %% [markdown]
# ### The probability that it will be a methane when the temperature is 27.5 and there is some lumps is : 0.1919816029214187
# ---

# %% [markdown]
# # Q4

# %%
Odds_a = is_mathane_prob_a[0] / (1-is_mathane_prob_a[0])
Odds_b = is_mathane_prob_a[1] / (1-is_mathane_prob_a[1])
Odds_c = is_mathane_prob_a[2] / (1-is_mathane_prob_a[2])

# %%
np.log(Odds_b / Odds_a)
# Out:
# -0.08010186705609014

# %%
np.log(Odds_c / Odds_b)
# Out:
# -0.08010186705608989

# %%
np.log(Odds_c / Odds_a)
# Out:
# -0.16020373411218017

# %% [markdown]
# ## As we can see , the log odds ratio between B and A and between C and B is equal and is similar to the temperature parameter. Thats because the difference between them is only with the temperature that is $1^\circ$ (they both have lumps).
# ## Log odds ratio between C and B and between B and A = 1*temp
# ## We can see aswell that the different between them and the log odds ratio between C and A is double the temperature parameter and that because the interval between C and A is double then between C and B and between B and A ($2^\circ$).
# ## Log odds ratio between C and A = 2*temp
# ---

# %% [markdown]
# # PART 2

# %%
df1 = pkl.load( open('../ניהול בטיחות למהנדסים/project_part_2_group_18.pkl', 'rb'))
df1.head()
# Out:
#    Intercept  age  safety_guidence_score factory__c    chemical__c  \
# 0        1.0   44                      0    Toronto  Sulfuric_Acid
# 1        1.0   35                      4  Vancouver  Sulfuric_Acid
# 2        1.0   24                     10    Toronto  Sulfuric_Acid
# 3        1.0   36                      2  Vancouver  Sulfuric_Acid
# 4        1.0   29                      8    Toronto  Sulfuric_Acid
#
#    time_in_factory  num_accidents
# 0                1              0
# 1                3              6
# 2                3              0
# 3                8              2
# 4                5              0

# %% [markdown]
# # Q1 :

# %%
df1['avg_accidents_per_year'] = df1['num_accidents'] / df1['time_in_factory']
average_accidents_per_factory = df1.groupby('factory__c')['avg_accidents_per_year'].sum().reset_index()
plt.figure(figsize=(12,8))
plt.bar(average_accidents_per_factory['factory__c'], average_accidents_per_factory['avg_accidents_per_year'], color='Pink')
plt.xlabel('Factory')
plt.ylabel('Average Accidents per Year')
plt.title('Average Number of Accidents per Year for Each Factory')
plt.xticks(rotation=45)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### It seems that the average number of accidents per year varies greatly between factories. Therefore, it can be assumed that the factory's location has an impact on the number of accidents. As a result, it is likely that the variable 'factory__c' will be significant.
# ---

# %% [markdown]
# # Q2 :

# %%
mean_accidents_per_year_by_age = df1.groupby('age')['avg_accidents_per_year'].sum().reset_index()
plt.figure(figsize=(10, 6))
plt.scatter(mean_accidents_per_year_by_age['age'], mean_accidents_per_year_by_age['avg_accidents_per_year'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Accidents per Year')
plt.title('Sum of Accidents per Year by Age')
plt.grid(True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### It seems there is a connection between the worker's age and the number of accidents. The connection appears to be negative, meaning that as the worker's age increases, the number of accidents decreases. Therefore, the sign in the equation will be negative (-) .
# ---

# %% [markdown]
# # Q3

# %%
dummy_factory = pd.get_dummies(df1['factory__c'])
df1 = pd.concat([df1 ,dummy_factory], axis=1)
df1.drop('Toronto', axis=1, inplace=True)

# %%
dummy_chemical = pd.get_dummies(df1['chemical__c'])
df1 = pd.concat([df1, dummy_chemical], axis=1)
df1.drop('Methane', axis=1, inplace=True)

# %%
df1.head()
# Out:
#    Intercept  age  safety_guidence_score factory__c    chemical__c  \
# 0        1.0   44                      0    Toronto  Sulfuric_Acid
# 1        1.0   35                      4  Vancouver  Sulfuric_Acid
# 2        1.0   24                     10    Toronto  Sulfuric_Acid
# 3        1.0   36                      2  Vancouver  Sulfuric_Acid
# 4        1.0   29                      8    Toronto  Sulfuric_Acid
#
#    time_in_factory  num_accidents  avg_accidents_per_year  Calgery  Montreal  \
# 0                1              0                    0.00        0         0
# 1                3              6                    2.00        0         0
# 2                3              0                    0.00        0         0
# 3                8              2                    0.25        0         0
# 4                5              0                    0.00        0         0
#
#    Saskatoon  Vancouver  Sulfuric_Acid
# 0          0          0              1
# 1          0          1              1
# 2          0          0              1
# 3          0          1              1
# 4          0          0              1

# %%
model_poisson = sm.GLM(df1['num_accidents'], df1[['Intercept', 'age' ,'safety_guidence_score','Calgery','Montreal','Saskatoon','Vancouver','Sulfuric_Acid']], family=sm.families.Poisson(), offset=np.log(df1['time_in_factory']))
results_poisson = model_poisson.fit()
print(results_poisson.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          num_accidents   No. Observations:                10000
# Model:                            GLM   Df Residuals:                     9992
# Model Family:                 Poisson   Df Model:                            7
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -24860.
# Date:                Fri, 16 Aug 2024   Deviance:                       28561.
# Time:                        09:44:59   Pearson chi2:                 3.39e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1076
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.1018      0.033     -3.085      0.002      -0.167      -0.037
# age                      -0.0191      0.001    -25.110      0.000      -0.021      -0.018
# safety_guidence_score     0.0094      0.002      5.000      0.000       0.006       0.013
# Calgery                  -0.0381      0.043     -0.889      0.374      -0.122       0.046
# Montreal                  0.0029      0.020      0.147      0.883      -0.036       0.042
# Saskatoon                -0.0167      0.021     -0.807      0.420      -0.057       0.024
# Vancouver                 0.2556      0.018     14.552      0.000       0.221       0.290
# Sulfuric_Acid            -0.0118      0.013     -0.908      0.364      -0.037       0.014
# =========================================================================================

# %% [markdown]
# ### As we can see there are non-significant variables and we need to drop them.

# %% [markdown]
# ### So the new regresion will be :

# %%
model_poisson1 = sm.GLM(df1['num_accidents'], df1[['Intercept', 'age' ,'safety_guidence_score','Vancouver']], family=sm.families.Poisson(), offset=np.log(df1['time_in_factory']))
results_poisson1 = model_poisson1.fit()
print(results_poisson1.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          num_accidents   No. Observations:                10000
# Model:                            GLM   Df Residuals:                     9996
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -24862.
# Date:                Fri, 16 Aug 2024   Deviance:                       28564.
# Time:                        09:45:00   Pearson chi2:                 3.39e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1074
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.1151      0.029     -3.927      0.000      -0.172      -0.058
# age                      -0.0191      0.001    -25.139      0.000      -0.021      -0.018
# safety_guidence_score     0.0093      0.002      4.980      0.000       0.006       0.013
# Vancouver                 0.2614      0.012     21.965      0.000       0.238       0.285
# =========================================================================================

# %% [markdown]
# ### Poisson regression equation:
# $$
# E[y_i] =  (\text{time_in_factory})_i \cdot e^{-0.1151 -0.0191 \cdot \text{age} + 0.0093 \cdot \text{safety_guidance_score} + 0.2614 \cdot \text{Vancouver}}
# $$
# ---
# ---

# %% [markdown]
# # Q4

# %% [markdown]
# ### First Check :

# %%
X = df1[['Intercept', 'age' ,'safety_guidence_score','Calgery','Montreal','Saskatoon','Vancouver','Sulfuric_Acid']]
y = df1['num_accidents']
df_pois = pd.concat((X, y), axis =1)
df_pois['predicted'] = results_poisson1.fittedvalues
lams = np.linspace(0,15, 30)

means = []
vars_ = []

for lams_ind in range(lams.shape[0]-1):
    
    lb = lams[lams_ind]
    ub = lams[lams_ind+1]
        
    shape = df_pois.loc[(df_pois['predicted']>lb)& (df_pois['predicted']<ub), 'num_accidents'].shape
    var = df_pois.loc[(df_pois['predicted']>lb)& (df_pois['predicted']<ub), 'num_accidents'].std()**2
    mean = df_pois.loc[(df_pois['predicted']>lb)& (df_pois['predicted']<ub), 'num_accidents'].mean()
    
    if shape[0] > 10:
        means.append(mean)
        vars_.append(var)
    
plt.figure()
plt.scatter(means, vars_)
plt.plot(means, means, '--', label='y = x', color = 'orange')
plt.xlabel('Mean', fontsize = 15)
plt.ylabel('Variance', fontsize = 15)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### We can see that the Variance is higher then the Mean

# %% [markdown]
# ### Second Check :

# %%
f, axes = plt.subplots(1, 2, figsize=(15, 6))
axes[0].scatter(df1['num_accidents'], results_poisson1.resid_response)
axes[0].set_ylabel("Residuals")
axes[0].set_xlabel("$y$")
axes[1].scatter(df1['num_accidents'], results_poisson1.resid_pearson)
axes[1].axhline(y=-2, linestyle=':', color='black', label='$\pm 2$')
axes[1].axhline(y=+2, linestyle=':', color='black')
axes[1].set_ylabel("Standardized residuals")
axes[1].set_xlabel("$y$")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RESP1 = np.array(results_poisson1.resid_pearson)
(RESP1<-2).sum() , (RESP1>2).sum()
# Out:
# (249, 1226)

# %%
RESP1.shape[0]
# Out:
# 10000

# %%
(249+1226)/10000
# Out:
# 0.1475

# %% [markdown]
# #### We can see that only 85% of the residuals fall within the ±2 range of standard deviations

# %% [markdown]
# ### Third Check :

# %%
R = results_poisson1.pearson_chi2 / results_poisson1.df_resid
print(R)
# Out:
# 3.3927199132930688

# %% [markdown]
# #### We have here an overdispersion !!

# %% [markdown]
# ### Forth Check :

# %%
from scipy.stats import chi2
df_resid = results_poisson1.df_resid
p_value = 1 - chi2.cdf(results_poisson1.pearson_chi2, df_resid)
p_value
# Out:
# 0.0

# %% [markdown]
# #### We can say that the assumption that the variable follows a Poisson distribution does not hold because we got a value smaller than 0.05.
# ---

# %% [markdown]
# # Q5

# %% [markdown]
# #### The main assumption in Poisson regression is that the mean is equal to the variance. When we check if 95% of the errors are within ±2 standard deviations, we are examining how the variance changes across different values. If 95% or more of the errors fall within this range, it indicates that the variance of the errors is relatively stable and doesn’t change much. This suggests that the errors follow a Poisson distribution and supports the assumption that the mean and variance are equal.
# ---

# %% [markdown]
# # Q6

# %% [markdown]
# #### We're going to do this because we don't have many data points for each mean, and to check for variance, we need to see the spread of the data. It's not possible to assess the spread with only a few points, so we'll use a method called 'bucketing.' This involves dividing the data points into several regions, and for each region, we'll calculate the mean and variance.
# ---

# %% [markdown]
# # Q7

# %%
df1.head()
# Out:
#    Intercept  age  safety_guidence_score factory__c    chemical__c  \
# 0        1.0   44                      0    Toronto  Sulfuric_Acid
# 1        1.0   35                      4  Vancouver  Sulfuric_Acid
# 2        1.0   24                     10    Toronto  Sulfuric_Acid
# 3        1.0   36                      2  Vancouver  Sulfuric_Acid
# 4        1.0   29                      8    Toronto  Sulfuric_Acid
#
#    time_in_factory  num_accidents  avg_accidents_per_year  Calgery  Montreal  \
# 0                1              0                    0.00        0         0
# 1                3              6                    2.00        0         0
# 2                3              0                    0.00        0         0
# 3                8              2                    0.25        0         0
# 4                5              0                    0.00        0         0
#
#    Saskatoon  Vancouver  Sulfuric_Acid
# 0          0          0              1
# 1          0          1              1
# 2          0          0              1
# 3          0          1              1
# 4          0          0              1

# %%
from statsmodels.discrete.discrete_model import NegativeBinomial
X = df1[['Intercept', 'age', 'safety_guidence_score', 'Calgery', 'Montreal', 'Saskatoon', 'Vancouver', 'Sulfuric_Acid']]
y = df1['num_accidents']
nb = NegativeBinomial(
    y,
    X,
    offset=np.log(df1["time_in_factory"].values),
)
result = nb.fit()
print(pd.DataFrame(result.params).loc['alpha',:])
# Out:
# Optimization terminated successfully.
#          Current function value: 2.083050
#          Iterations: 31
#          Function evaluations: 39
#          Gradient evaluations: 39
# 0    0.759349
# Name: alpha, dtype: float64

# %%
alpha = 0.759349
model_NB = sm.GLM(
    y,
    X,
    offset=np.log(df1["time_in_factory"]),
    family=sm.families.NegativeBinomial(alpha=alpha),
)
result_NB = model_NB.fit()
print(result_NB.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          num_accidents   No. Observations:                10000
# Model:                            GLM   Df Residuals:                     9992
# Model Family:        NegativeBinomial   Df Model:                            7
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -20830.
# Date:                Fri, 16 Aug 2024   Deviance:                       11115.
# Time:                        09:45:04   Pearson chi2:                 1.26e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):            0.03216
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.0914      0.062     -1.480      0.139      -0.212       0.030
# age                      -0.0187      0.001    -13.244      0.000      -0.021      -0.016
# safety_guidence_score     0.0067      0.003      1.907      0.057      -0.000       0.014
# Calgery                  -0.0115      0.076     -0.152      0.879      -0.160       0.137
# Montreal                  0.0088      0.036      0.246      0.805      -0.061       0.079
# Saskatoon                -0.0051      0.037     -0.138      0.890      -0.078       0.068
# Vancouver                 0.2727      0.032      8.393      0.000       0.209       0.336
# Sulfuric_Acid            -0.0194      0.024     -0.800      0.423      -0.067       0.028
# =========================================================================================

# %% [markdown]
# ### As we can see there are non-significant variables and we need to drop them.

# %% [markdown]
# ### So the new regresion will be :

# %%
X = df1[['age', 'safety_guidence_score', 'Vancouver']]
y = df1['num_accidents']
nb = NegativeBinomial(
    y,
    X,
    offset=np.log(df1["time_in_factory"].values),
)
result = nb.fit()
print(pd.DataFrame(result.params).loc['alpha',:])
# Out:
# Optimization terminated successfully.
#          Current function value: 2.083263
#          Iterations: 12
#          Function evaluations: 20
#          Gradient evaluations: 20
# 0    0.760043
# Name: alpha, dtype: float64

# %%
alpha = 0.760043
model_NB = sm.GLM(
    y,
    X,
    offset=np.log(df1["time_in_factory"]),
    family=sm.families.NegativeBinomial(alpha=alpha),
)
result_NB2 = model_NB.fit()
print(result_NB2.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          num_accidents   No. Observations:                10000
# Model:                            GLM   Df Residuals:                     9997
# Model Family:        NegativeBinomial   Df Model:                            2
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -20833.
# Date:                Mon, 12 Aug 2024   Deviance:                       11114.
# Time:                        22:19:26   Pearson chi2:                 1.26e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.03173
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# age                      -0.0211      0.001    -36.490      0.000      -0.022      -0.020
# safety_guidence_score     0.0045      0.003      1.363      0.173      -0.002       0.011
# Vancouver                 0.2650      0.022     11.956      0.000       0.222       0.308
# =========================================================================================

# %% [markdown]
# ### We can see that the 'safety_guidence_score' is non-significant aswell.

# %%
X = df1[['age', 'Vancouver']]
y = df1['num_accidents']
nb = NegativeBinomial(
    y,
    X,
    offset=np.log(df1["time_in_factory"].values),
)
result = nb.fit()
print(pd.DataFrame(result.params).loc['alpha',:])
# Out:
# Optimization terminated successfully.
#          Current function value: 2.083355
#          Iterations: 10
#          Function evaluations: 17
#          Gradient evaluations: 17
# 0    0.760563
# Name: alpha, dtype: float64

# %%
alpha = 0.760563
model_NB = sm.GLM(
    y,
    X,
    offset=np.log(df1["time_in_factory"]),
    family=sm.families.NegativeBinomial(alpha=alpha),
)
result_NB3 = model_NB.fit()
print(result_NB3.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:          num_accidents   No. Observations:                10000
# Model:                            GLM   Df Residuals:                     9998
# Model Family:        NegativeBinomial   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -20834.
# Date:                Mon, 12 Aug 2024   Deviance:                       11112.
# Time:                        22:19:27   Pearson chi2:                 1.26e+04
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.03153
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age           -0.0205      0.000    -53.958      0.000      -0.021      -0.020
# Vancouver      0.2667      0.022     12.040      0.000       0.223       0.310
# ==============================================================================

# %% [markdown]
# ### Now we checking if 95% of the errors are within ±2 standard deviations.

# %%
f, axes = plt.subplots(1, 2, figsize=(15, 6))
axes[0].plot(y, result_NB.resid_response, 'o')
axes[0].set_ylabel("Residuals")
axes[0].set_xlabel("$y$")
axes[1].plot(y, result_NB.resid_pearson, 'o')
axes[1].axhline(y=-2, linestyle=':', color='black', label='$\pm 2$')
axes[1].axhline(y=+2, linestyle=':', color='black')
axes[1].set_ylabel("Standardized residuals")
axes[1].set_xlabel("$y$")
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
RESP2 = np.array(result_NB.resid_pearson)
(RESP2<-2).sum() , (RESP2>2).sum()
# Out:
# (0, 535)

# %%
RESP2.shape[0]
# Out:
# 10000

# %%
535/10000
# Out:
# 0.0535

# %% [markdown]
# ### We can see that it's almost 95%, which is better than the Poisson regression. Therefore, we would prefer to use it, although it's still not perfect.

# %% [markdown]
# ## IRR :

# %%
print("IRR[Vancouver] = ", np.exp(0.2667))
# Out:
# IRR[Vancouver] =  1.3056486929626985

# %% [markdown]
# #### Being in Vancouver compared to the baseline location increases the accident rate by about 30.56%.

# %% [markdown]
# # Q8

# %% [markdown]
# ### Prediction when we not removing the non-significant variables

# %%
pred_df_bn = pd.DataFrame([])
pred_df_bn.loc[0,'Intercept'] = 1
pred_df_bn.loc[0,'age'] = 30
pred_df_bn.loc[0,'safety_guidence_score'] = 8
pred_df_bn.loc[0,'Calgery'] = 0
pred_df_bn.loc[0,'Montreal'] = 0
pred_df_bn.loc[0,'Saskatoon'] = 0
pred_df_bn.loc[0,'Vancouver'] = 0
pred_df_bn.loc[0,'Sulfuric_Acid'] = 0
pred_df_bn
# Out:
#    Intercept   age  safety_guidence_score  Calgery  Montreal  Saskatoon  \
# 0        1.0  30.0                    8.0      0.0       0.0        0.0
#
#    Vancouver  Sulfuric_Acid
# 0        0.0            0.0

# %%
OurPrediction = 3 * result_NB.predict(pred_df_bn[['Intercept', 'age', 'safety_guidence_score', 'Calgery', 'Montreal', 'Saskatoon', 'Vancouver', 'Sulfuric_Acid']])
OurPrediction
# Out:
# 0    1.649621
# dtype: float64

# %% [markdown]
# ### Prediction when we do removing the non-significant variables

# %%
pred_df_bn2 = pd.DataFrame([])
pred_df_bn2.loc[0,'age'] = 30
pred_df_bn2.loc[0,'safety_guidence_score'] = 8
pred_df_bn2.loc[0,'Vancouver'] = 0
pred_df_bn
# Out:
#    Intercept   age  safety_guidence_score  Calgery  Montreal  Saskatoon  \
# 0        1.0  30.0                    8.0      0.0       0.0        0.0
#
#    Vancouver  Sulfuric_Acid
# 0        0.0            0.0

# %%
OurPrediction2 = 3 * result_NB2.predict(pred_df_bn[['age', 'safety_guidence_score', 'Vancouver']])
OurPrediction2
# Out:
# 0    1.6524
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Q9

# %% [markdown]
# ### The meaning of the result we obtained is that the predicted number of accidents for a worker aged 30, who has worked for 3 years, with a safety guidance score of 8, at a factory in Toronto, and working with methane, is 1.649621.
# ---

# %% [markdown]
# # Q10

# %%
df1['age'].max(),df1['age'].min()
# Out:
# (49, 23)

# %%
ages = np.arange(23, 49) 
safety_guidence_scores = np.arange(1, 11)  
prediction_df = pd.DataFrame([(age, score) for age in ages for score in safety_guidence_scores], 
                    columns=['age', 'safety_guidence_score'])
prediction_df['Intercept'] = 1.0
prediction_df['Calgery'] = 0
prediction_df['Montreal'] = 0
prediction_df['Saskatoon'] = 0
prediction_df['Vancouver'] = 0
prediction_df['Sulfuric_Acid'] = 0

# %%
prediction_df['Prediction'] = 5 * result_NB.predict(prediction_df[['Intercept', 'age', 'safety_guidence_score', 'Calgery', 'Montreal', 'Saskatoon', 'Vancouver', 'Sulfuric_Acid']])

# %%
prediction_df.head()
# Out:
#    age  safety_guidence_score  Intercept  Calgery  Montreal  Saskatoon  \
# 0   23                      1        1.0        0         0          0
# 1   23                      2        1.0        0         0          0
# 2   23                      3        1.0        0         0          0
# 3   23                      4        1.0        0         0          0
# 4   23                      5        1.0        0         0          0
#
#    Vancouver  Sulfuric_Acid  Prediction
# 0          0              0    2.990402
# 1          0              0    3.010387
# 2          0              0    3.030506
# 3          0              0    3.050758
# 4          0              0    3.071147

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.title('Number of accidents' ,fontsize = 24)
ax.scatter(prediction_df['age'] , prediction_df['safety_guidence_score'], prediction_df['Prediction'] , c='r', marker='o')
ax.set_xlabel('Age',fontsize = 13)
ax.set_ylabel('Safety Guidence Score',fontsize = 13)
ax.set_zlabel('Accidents',fontsize = 13)
plt.show()
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ---

# %% [markdown]
# # Q11

# %% [markdown]
# ### There are a few key differences between linear regression and Poisson regression. In linear regression, the support will be any number from negative infinity to positive infinity, whereas in Poisson regression, the support will be a non-negative integer (from 0 to infinity).
# ### In any regression model, we are predicting the expected value (or mean) of the dependent variable based on the values of the independent variables. We also assume that the true values of the dependent variable are distributed around this mean according to the distribution that matches the type of regression we are using.
# ### Linear regression uses the method of OLS (Ordinary Least Squares) to estimate the parameters, while Poisson regression uses 'Maximum Likelihood' estimation .
# ### We prefer to use linear regression when we have continuous data, not binary (0 or 1) data like in logistic regression, and we want to estimate some specific quantity. In general, linear regression is simpler and faster, but it requires certain assumptions to be met, including:
# ### 1. Linearity: The relationship between the variables is linear.
# ### 2. Homoscedasticity: The variance of the errors is constant across all levels of the independent variables.
# ### 3. Normality: The errors (or residuals) are normally distributed.
